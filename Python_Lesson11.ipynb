# %%
number = 1000
profit1 = (1000 * 1.07)
profit2 = (profit1 * 1.07)
profit3 = (profit2 * 1.07)
profit4 = (profit3 * 1.07)
profit5 = (profit4 * 1.07)
profit6 = (profit5 * 1.07)
profit7 = (profit6 * 1.07)
print (int(profit7))
# Out:
# 1605

# %%
profit = (1000 + (1000 + 0.07)**7)
print (profit)
# Out:
# 1.0004901029120062e+21

# %% [markdown]
# ##

# %%
kadayıf = True
su = True 
şeker = True
fındık = True
fıstık = False
ceviz = False
yumurta = True
çay = True
meşrubat = True
limonata = True
yedim = kadayıf and (su and şeker) and (fındık or fıstık or ceviz) and yumurta \
    and (çay or meşrubat or limonata)
yedim
# Out:
# True

# %%
para = 1000
para = para + para * 0.07 # monday
para
# Out:
# 1070.0

# %%
para = para + para * 0.07 # tue
para
# Out:
# 1144.9

# %%
para = para + para * 0.07 # wed
para
# Out:
# 1225.0430000000001

# %%
para = para + para * 0.07 # thur
para
# Out:
# 1310.79601

# %%
para = para + para * 0.07 # fri
para
# Out:
# 1402.5517307

# %%
para = para + para * 0.07 # sat
para
# Out:
# 1500.730351849

# %%
para = para + para * 0.07 # sun
para
# Out:
# 1605.78147647843

# %%
para= 1000
para = para * 1.07**7
para
# Out:
# 1605.7814764784307

# %%
animal = "hippopotamus"
print (animal[1:])
print (animal[:6])
print (animal[::2])
print (animal[1:7:2])
print (animal[-3:])
print (animal[::-1])
# Out:
# ippopotamus
# hippop
# hpooau
# ipp
# mus
# sumatopoppih

# %%
sonuc = str( (5+6) ** 2) + "121"
sonuc
# Out:
# '121121'

# %%
sonuc = (sonuc + sonuc ) * 2 
sonuc
# Out:
# '...'

# %%
string_1='I am angry...'
print (* string_1)
string_2='1453'
print (* string_2)
# Out:
# I   a m   a n g r y . . .
# 1 4 5 3

# %%
deneme = "clarusway"
deneme.format ()
# Out:
# 'clarusway'

# %%
saat : '05:00'
yer = 'okul'
miktar = 2
